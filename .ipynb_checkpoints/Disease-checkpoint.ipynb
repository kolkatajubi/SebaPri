# %%
have_disease=0.001
not_have_disease=1-have_disease
accuracy=0.985
no_accuracy=1-accuracy

# %%
P_Disease_Positive=(have_disease*accuracy)/(have_disease*accuracy+not_have_disease*no_accuracy)
P_noDisease_Positive=(not_have_disease*no_accuracy)/(have_disease*accuracy+not_have_disease*no_accuracy)

# %%
print (P_Disease_Positive)
print (P_noDisease_Positive)
# Out:
# 0.061678146524733815
# 0.9383218534752661

# %%
number_of_test=0
P_noDisease_Positive_Negative=P_noDisease_Positive
P_Disease_Positive_Negative=P_Disease_Positive
while(P_noDisease_Positive_Negative<0.99):
    number_of_test+=1
    P_noDisease_Positive_Negative=(P_noDisease_Positive_Negative*accuracy)/(P_noDisease_Positive*accuracy+P_Disease_Positive_Negative*no_accuracy)
    print ("Test Number : ",number_of_test)
    print ("Probability : ",P_noDisease_Positive_Negative)
# Out:
# Test Number :  1
# Probability :  0.999
# Test Number :  2
# Probability :  1.063602
# Test Number :  3
# Probability :  1.1323815959999999
# Test Number :  4
# Probability :  1.2056089392079998
# Test Number :  5
# Probability :  1.2835716506101171
# Test Number :  6
# Probability :  1.3665759506829047
# Test Number :  7
# Probability :  1.4549478621603993
# Test Number :  8
# Probability :  1.5490344905801052
# Test Number :  9
# Probability :  1.6492053876376187
# Test Number :  10
# Probability :  1.7558540027048515
# Test Number :  11
# Probability :  1.8693992282130985
# Test Number :  12
# Probability :  1.990287044970879
# Test Number :  13
# Probability :  2.118992273878996
# Test Number :  14
# Probability :  2.256020440923171
# Test Number :  15
# Probability :  2.4019097627695363
# Test Number :  16
# Probability :  2.5572332607619663
# Test Number :  17
# Probability :  2.7226010116245734
# Test Number :  18
# Probability :  2.898662543709629
# Test Number :  19
# Probability :  3.086109388202852
# Test Number :  20
# Probability :  3.2856777953066367
# Test Number :  21
# Probability :  3.498151626069799
# Test Number :  22
# Probability :  3.7243654312223127
# Test Number :  23
# Probability :  3.9652077291080223
# Test Number :  24
# Probability :  4.2216244955903415
# Test Number :  25
# Probability :  4.494622879638516
# Test Number :  26
# Probability :  4.7852751591884735
# Test Number :  27
# Probability :  5.094722952815995
# Test Number :  28
# Probability :  5.424181703764762
# Test Number :  29
# Probability :  5.77494545394155
# Test Number :  30
# Probability :  6.14839192662977
# Test Number :  31
# Probability :  6.545987937885163
# Test Number :  32
# Probability :  6.969295157868403
# Test Number :  33
# Probability :  7.419976244743893
# Test Number :  34
# Probability :  7.899801375237331
# Test Number :  35
# Probability :  8.41065519750268
# Test Number :  36
# Probability :  8.954544233607852
# Test Number :  37
# Probability :  9.533604760714493
# Test Number :  38
# Probability :  10.150111201907364
# Test Number :  39
# Probability :  10.806485059630708
# Test Number :  40
# Probability :  11.50530442682016
# Test Number :  41
# Probability :  12.249314113087864
# Test Number :  42
# Probability :  13.041436425734211
# Test Number :  43
# Probability :  13.88478264793169
# Test Number :  44
# Probability :  14.782665259164606
# Test Number :  45
# Probability :  15.738610945923917
# Test Number :  46
# Probability :  16.75637445376033
# Test Number :  47
# Probability :  17.8399533351035
# Test Number :  48
# Probability :  18.993603650773522
# Test Number :  49
# Probability :  20.221856686856874
# Test Number :  50
# Probability :  21.52953675260695
# Test Number :  51
# Probability :  22.921780129275533
# Test Number :  52
# Probability :  24.40405524430202
# Test Number :  53
# Probability :  25.982184150100217
# Test Number :  54
# Probability :  27.662365391806695
# Test Number :  55
# Probability :  29.451198353810195
# Test Number :  56
# Probability :  31.35570918068992
# Test Number :  57
# Probability :  33.38337837437454
# Test Number :  58
# Probability :  35.54217017591742
# Test Number :  59
# Probability :  37.84056384729341
# Test Number :  60
# Probability :  40.287586976085045
# Test Number :  61
# Probability :  42.89285093387188
# Test Number :  62
# Probability :  45.666588627595594
# Test Number :  63
# Probability :  48.61969469218011
# Test Number :  64
# Probability :  51.76376828227442
# Test Number :  65
# Probability :  55.11115863119483
# Test Number :  66
# Probability :  58.675013556012104
# Test Number :  67
# Probability :  62.46933109930088
# Test Number :  68
# Probability :  66.50901451038901
# Test Number :  69
# Probability :  70.80993078206083
# Test Number :  70
# Probability :  75.3889729726341
# Test Number :  71
# Probability :  80.26412655819776
# Test Number :  72
# Probability :  85.45454007562788
# Test Number :  73
# Probability :  90.98060033385181
# Test Number :  74
# Probability :  96.86401248877422
# Test Number :  75
# Probability :  103.12788529638162
